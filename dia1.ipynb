# %%
print('Hola mundo')
# Out:
# Hola mundo

# %%
#Practica de texto
nombre='denilson'
edad= '27,'
ciudad='lambare'

print('Me llamo', nombre, 'tengo', edad, 'y vivo en', ciudad)
# Out:
# Me llamo denilson tengo 27, y vivo en lambare

# %%
# Practicas con numeros
    #Variables
Producto1= 12000
producto2= 60000
Dolar= 6000
#Sumas
print('Suma:',Producto1+producto2)

#Resta
print('Resta:',Producto1-producto2)

#Multiplicacion
print('Multiplicacion:', Producto1*producto2)

#Division
print('Division:', producto2/Producto1)

#Division 2
print('Division2:', producto2//Producto1)

#Dolar
print('Dolar:',Producto1/Dolar)
print('Dolar:',Dolar/Producto1)
print('Dolar:',producto2/Dolar)
print('Dolar:',Dolar/producto2)

#Dolar 2
print('Dolar:',Producto1//Dolar)
print('Dolar:',Dolar//Producto1)
print('Dolar:',producto2//Dolar)
print('Dolar:',Dolar//producto2)
# Out:
# Suma: 72000
# Resta: -48000
# Multiplicacion: 720000000
# Division: 5.0
# Division2: 5
# Dolar: 2.0
# Dolar: 0.5
# Dolar: 10.0
# Dolar: 0.1
# Dolar: 2
# Dolar: 0
# Dolar: 10
# Dolar: 0

# %%
#Challenge 3
    #suma
#variable
cantidad_de_manzanas= 5
cantidad_de_naranjas= 8
#operacion
Cantidad_de_frutas= cantidad_de_manzanas+cantidad_de_naranjas
print('Cantidad de frutas:',Cantidad_de_frutas)

    #resta
#varianble
Frutas_vendidas=20
Frutas_restantes= Frutas_vendidas-Cantidad_de_frutas
print('Frutas restantes:', Frutas_restantes)
# Out:
# Cantidad de frutas: 13
# Frutas restantes: 7

# %%
nomrbe= 'Denilson'
apellido= 'Recalde'
espacio= ' '
print(nombre + espacio + apellido)
print(f'hola mi nombre es {nombre} y mi apellido es {apellido}')
#utilizamos el print(f') para concatenar mas facil sin otra variable como el espacio
# Out:
# denilson Recalde
# hola mi nombre es denilson y mi apellido es Recalde

# %%
#Challenger 4
#variables
nombre = 'Thiago'
apellido = 'Villanueva'
nombre2 = 'Denilson'
#operacion
print(f'Hola. {nombre} {apellido} mucho gusto, mi nombre es {nombre2} es un gusto conocerte.')
# Out:
# Hola. Thiago Villanueva mucho gusto, mi nombre es Denilson es un gusto conocerte.

# %%
#solicitar producto al usuario

producto = input('que producto necesita')
print(f'Producto solicitado: {producto}')
# Out:
# Producto solicitado: loto

# %%
#challenger 5
#Variables
Cantidad_de_producto = input('cantidad de producto')
Hora_de_envio = input ('hora de envio')
print(f'Cantidad de producto: {Cantidad_de_producto}')
print(f'Horario de envio {Hora_de_envio} Hs')
# Out:
# Cantidad de producto: 2
# Horario de envio 2 Hs

# %%
Naranjas =int(input('naranjas'))
limones = int(input('limones'))

print(f'Total del resultado:',Naranjas + limones)
# Out:
# Total del resultado: 11

# %%
numero1 = int(input('primer numero'))
numero2 = int(input('segundo numero'))

print(f'suma de numero: {numero1+numero2}')
# Out:
# suma de numero: 7

# %%
#DEF definicion de variable
def preparar_terere():
    print('buscar la jarra y guampa')
    print('poner hielo, agua y yerva')
    print('disfrutar')

preparar_terere()
preparar_terere()
preparar_terere()
# Out:
# buscar la jarra y guampa
# poner hielo, agua y yerva
# disfrutar
# buscar la jarra y guampa
# poner hielo, agua y yerva
# disfrutar
# buscar la jarra y guampa
# poner hielo, agua y yerva
# disfrutar

# %%
#challenger 6
def Ferreteria(articulo,color):
    print(f'Que necesita?', (articulo),'que color desea?', (color))

Ferreteria('pintura','azul')
# Out:
# Que necesita? pintura que color desea? azul

# %%
def Ferreteria(articulo,color)
    print(f'que desea comprar'(articulo), de que color necesita (color))

def articulos()
    articulo= input('elemento a comprar')
    color= input('elemento')

    
Ferreteria()

# %%
def Articulo_a_comprar(tipo,tamano,color):
    print(f'caracteristica1{tipo}, caracteristica2 {tamano}, caracteristica3 {color}')

def Compra():
    tipo= input('caracteristica1')
    tamano= input('caracteristica2')
    color= input('caracteristica3')

    Articulo_a_comprar('tipo=,tamano,color')
