# %%
#diccionario
mi_contacto = {'nombre': 'denilson', 'apellido':'recalde'}
print(mi_contacto)

mi_contacto['nombre']
print(mi_contacto['nombre'])
#importante el uso de las comillas,parentesis, corchete

#modifica el elemento del diccionario
mi_contacto['nombre'] = 'edgardo'
print(mi_contacto['nombre'])

#usar metodo del dicionario
print(mi_contacto.keys()) #devuelve todas las claves del diccionario
print(mi_contacto.values()) # devuelve todas los vaores de ldiccionario
print(mi_contacto.items()) # debvuelve el par

#anadir mas datos al diccionario
mi_contacto['ciudad'] = 'Asuncion'
print(mi_contacto)

#eliminar el ultimo elemento 
mi_contacto.popitem()  #elimina el ultimo mencionado

#eliminar datos del diccionario por clave
del mi_contacto['apellido']
print(mi_contacto)

#los diccionarios son iterables
for valores in mi_contacto.values():
    print(valores)
# Out:
# {'nombre': 'denilson', 'apellido': 'recalde'}
# denilson
# edgardo
# dict_keys(['nombre', 'apellido'])
# dict_values(['edgardo', 'recalde'])
# dict_items([('nombre', 'edgardo'), ('apellido', 'recalde')])
# {'nombre': 'edgardo', 'apellido': 'recalde', 'ciudad]': 'Asuncion'}
# {'nombre': 'edgardo'}

# %%
# Challenge 1 🤺 10m
# Escribir un programa que cree un diccionario vacío y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le pida al usuario. 

# Cada vez que se añada un nuevo dato debe imprimirse el contenido del diccionario.
# #palabras nombre apellido correo sexo
# #numbero edad telefono


informacion = {}
informacion['nombre'] = input('cual es su nombre')
informacion['apellido'] = input('cual es su apellido')
informacion['edad'] = int(input('cual seria su edad'))
informacion['telefono'] = int(input('cual seria su telefono'))
informacion['mail'] = input('cual es su mail')

print('Datos de la persona:', informacion)
#COMPLETADO
# Out:
# Datos de la persona: {'nombre': 'denilson', 'apellido': 'recalde', 'edad': 27, 'telefono': 976688229, 'mail': 'recaldedi8@gmail.com'}

# %%
diccionario1 = {} # Primero creamos el diccionario
print(diccionario1)

clave = 'dato'

while True:
    clave = input('Ingrese el dato que va ingresar')
    if clave == 'salir':
        print('Se ha terminado de ingresar los datos')
        break
    valor = input ('Ingrese el dato especificado anteriormente')
    diccionario1[clave]= [valor]
    print(diccionario1)
# Out:
# {}
# {'deni': ['deni']}
# {'deni': ['']}

# %%
# Crear una tarjeta personal. El usuario (mediante input) puede elegir:
# Crear datos nuevos
# Modificar datos
# Eliminar datos
# 'Crear datos nuevos', 'modificar datos','eliminar datos'

tarjeta_personal = {'apellido', 'edad'}
consulta = int(input('Crear datos nuevos(0)''modificar datos(1)''eliminar datos(2)'))
if consulta == 0 :
    creacion = input('que quiere crear')
    agregar = input('escriba')
    tarjeta_personal[creacion] = agregar 
elif consulta == 1 :
    tarjeta_personal = print(input('cual seria su nombre'))
print(tarjeta_personal)
### INCOMPLETO
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 12
#      10     creacion = input('que quiere modificar')
#      11     agregar = input('escribe la modificacion')
# ---> 12     tarjeta_personal[creacion] = agregar
#      13 elif consulta == 1 :
#      14     tarjeta_personal = print(input('cual seria su nombre'))
#
# TypeError: 'set' object does not support item assignment

# %%
agenda_de_contacto = {'contacto1', '0981111111', 'contacto2', '0982222222', 'contacto3', '0983333333'}

while True:
consulta = int(input('ver contactos(1), crear contacto(2), modificar contacto(3)'))
if consulta == 2 :
    creacion_de_nuevo_contacto = input('ingrese nombre')
    numero_del_contacto = int(input('ingrese numero'))
    agenda_de_contacto[creacion_de_nuevo_contacto]=numero_del_contacto
    print(agenda_de_contacto)
    
else:
    print(agenda_de_contacto)
#### NO TERMINADO
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 6
#       4 if consulta == 2 :
#       5     creacion_de_nuevo_contacto = input('ingrese nombre')
# ----> 6     numero_del_contacto = int(input('ingrese numero'))
#       7     agenda_de_contacto[creacion_de_nuevo_contacto]=numero_del_contacto
#       8     print(agenda_de_contacto)
#
# ValueError: invalid literal for int() with base 10: 'dfdf'

# %%
tarjeta={}

while True:
    accion=int(input("que desea realizar,1=crear,2=modificar,3=eliminar "))
  
    if accion==1:
        clave_1=input("ingrese la clave")
        valor_1=input("ingrese el valor para la clave")
        tarjeta[clave_1]=valor_1
        print(tarjeta)
    elif accion==2:
        print("los valores que podes modificar son son")
        print(tarjeta.items())
        clave_1=input("ingrese la clave a cambiar")
        modificacion=input("ingrese el valor nuevo")
        tarjeta[clave_1]=modificacion
        print(tarjeta)
    elif accion==3:
        print("los valores que podes eliminar son")
        print(tarjeta.keys())
        clave_1=input("ingresa el valor a eliminar")
        del tarjeta[clave_1]
        print(tarjeta)
    parar=input("si desea salir ingrese si sino ingrese no")
    if parar=="si":
        break

# %%
# Challenge 🤺  - 15 min
# Crear una clase animales que tenga atributo de clase y de instancia.

# Atributos de clase: especie.
# Atributos de instancia: nombre & color
# .
# Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
# Ejemplo: "Me llamo {nombre} y soy un ave de color {color}".

#definir la clase
class Aves:
    especie = 'voladora'
#definir los atributos
    def __init__(self, nombre, color):
        self.nombre = nombre 
        self.color = color 
#crear la instancia
aves1 = Aves('carlos', 'verde')
aves2 = Aves('federico', 'rojo')

print(aves1.color)
print(aves2.color)

print(f'me llamo{aves1} y soy de color')
# Out:
# verde
# rojo

# %%
class Super:
    especie = 'superhumanos'

    def __init__(self, nombre):
        self.nombre = nombre

    def rayos_laser(self):
        print('rayo laser rojo')

    def volar(self, km):
        print(f'vuelo a este {km} km ')

    def fuerza(self, objeto, tonelada)
        print(f'puedo alzar un {objeto} de {tonelada} tonelada')

# %%
#Crear dos métodos para nuestro animal y ejecutar, debe ser algo específico de ese animal.
# Ejemplo: "Cuando hablo, digo X".
# Ejemplo: "Cuando me muevo, hago X".
class Perro:
    especie = "canina"

    def __init__(self, ladrar, dormir):
        self.ladrar = ladrar
        self.dormir = dormir

    def ladrar(self):
        print(f'Cuando hablo tiene que {ladrar}')

perro1 = Perro('Guau','media hora')
perro2 = Perro('Miau','dos horas') 


print('Cuanto quieres dormir', perro1.dormir)
print('habla animal', perro2.ladrar)
# Out:
# Cuanto quieres dormir media hora
# habla animal Miau

# %%
class AnimalDeGranja:
    #atributo de clase:
    tipo = 'animales de granja'

    #atributos de instancia:
    def __init__(self,nombre, color, sonido):
        self.nombre = nombre
        self.color = color
        self.sonido = sonido

    #metodos (acciones de la clase)
    def hablar(self):
        print(f'hablo y digo {self.sonido}')

    def presentarse(self):
        print(f'hola soy {self.nombre}')

class Gallina(AnimalDeGranja):
    huevos_por_dia = 1

    def poner_huevos(self):
        print(f'estoy poniendo {self.huevos_por_dia} huevos por dia')

class Vaca(Gallina):
    patas = 4

    def mujir(selft):
        print("muuuu")

gallina1 = Gallina('carlos','marron','cocoroo')
gallina1.hablar()
gallina1.presentarse()

vaca = Vaca('lola','blanco','muuuu')
vaca.hablar()
vaca.mujir()
vaca.patas
# Out:
# hablo y digo cocoroo
# hola soy carlos
# hablo y digo muuuu
# muuuu
# 4

# %%
# Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.

# Observación: Editar las clases hijas para que no se inicialicen.

#definir una clase madre
class Pinturas:
    especie = 'colores'
#atributos de intancia
    def __init__(self, colores, tamano,):
        self.colores = colores
        self.tamano = tamano

    def Color1(self):
        print(f'el color que desa es {self.colores}')

    def tamano(self):
        print(f'que tamano seria{self.tamano}')

class Lamina(Pinturas):
    lamina1 = 'color rojo'
    print()

# %%
class Personas:
    especie = 'humanos'
    def __init__(self, nombre, apellido):
        self.nombre = nombre
        self.apellido = apellido

class Hija1(Personas):
    def n1(self):
        print(f'Nombre {self.nombre}')

class Hija2(Personas):
    def n2(self):
        print(f'apellido{self.apellido}')

objeto1 = Hija1('ara','recal')

objeto1.apellido

print(f'resultado aqui: {objeto1.apellido}')
# Out:
# resultado aqui: recal

# %%
class Persona: 
    def __init__(self, nombre, edad):
        self.nombre=nombre
        self.edad=edad

class Estudiante(Persona):
    pass

class Profesor(Persona):
    pass

estudiante1= Estudiante('Julio', 20)
prof1=Profesor('Julito', 35)

print(estudiante1.nombre, estudiante1.edad)
print(prof1.nombre, prof1.edad)
# Out:
# Julio 20
# Julito 35

# %%
# Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
# Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.

# Ejemplo: Yo me llamo pepito y tengo super fuerza
# Ejemplo: Yo me llamo juanito y puedo volar

class Humano:
    def __init__(self, habilidad1, habilidad2):
        self.habilidad1 = habilidad1
        self.habilidad2 = habilidad2

class Super1(Humano):
    def sup1(self):
        print({self.habilidad1})

class Super2(Humano):
    def sup2(self):
        print({self.habilidad2})

poder1 = Super1('telequinesis','combustion espontanea')
poder2 = Super2('invisibilidad','teletransportacion')

poder1.habilidad1
poder2.habilidad1
print(f'Soy Batman y mi poder es la {poder1.habilidad1}')
print(f'Soy Aquaman y mi poder es la {poder2.habilidad1}')
# Out:
# Soy Batman y mi poder es la telequinesis
# Soy Aquaman y mi poder es la invisibilidad
