# %%
#challenge 1 grupal
#crear una variable de nombre "palabra"
variable1 = 'palabra'

#crear una funcion y definir la palabra con "imprimir_palabra" sin que tenga parametro
def imprimir_palabra():

    #se imprime la variable que se creo "variable1" para que aparezca la "palabra"
    print(variable1) 
    
#se invoca a la funcion para ejecutar
imprimir_palabra()
# Out:
# palabra

# %%
#challenger 2 grupal
numero1 = 5
numero2 = 10
print(f'La suma es igual a: {numero1 + numero2}')

n1 = int(input('N1:'))
n2 = int(input('N2:'))
print(f'Suma de numero es igual a:{n1+n2}')

#definir una funcion

def suma(r1, r2) :
    r3 = r1 + r2
    print(f'r3: {r3}')

suma(n1, n2)
# Out:
# La suma es igual a: 15
# Suma de numero es igual a:60
# r3: 60

# %%
#challenge 1
letra1 = input('x')
letra2 = input('z')
def verificar_letra (l1,l2) :
    if l1 == l2  :
        print('las letras son iguales')

    else:
        print('las letras son diferentes')

verificar_letra(letra1, letra2)
# Out:
# las letras son iguales

# %%
#Ejemplo
def retirar_dinero(dinero):
    return dinero

dinero_retirado = retirar_dinero(50000)
print(f'dinero retirado', {dinero_retirado})

retirar_dinero(dinero_retirado + 10000)
# Out:
# dinero retirado {50000}
# 60000

# %%
#challenge2

palabra = input('ingrese la palabra')
numero = int(input('ingrese el numero'))

def palabras_numero (palabra, numero):
    if numero == len(palabra):
        return True
    else:
        return False
    
palabras_numero(palabra, numero)
# Out:
# True

# %%
#chellenge3

palabra = input('ingrese la palabra')
letra = 'a'

def letra_palabra(palabra, letra) :
    if letra in palabra :
        return {palabra}
    else:
        return letra

letra_palabra(palabra, letra)
# Out:
# 'a'

# %%
#challe4

palabras_ingresadas = list()

palabra = input('ingresa el codigo')

palabra_lista = list(palabra)

palabras_ingresadas.append(palabra_lista)
print(palabras_ingresadas)
# Out:
# [['h', 'o', 'l', 'a']]

# %%
for i in range(3):
    print(palabras_ingresadas)
palabras_ingresadas = list()
palabra = input('ingresa el codigo')
palabra_lista = list(palabra)
palabras_ingresadas.append(palabra_lista)
print(palabras_ingresadas)
# Out:
# [['h', 'o', 'l', 'a']]
# [['h', 'o', 'l', 'a']]
# [['h', 'o', 'l', 'a']]
# [['h', 'o', 'l', 'a']]

# %%
# Dada la lista de ejemplo: 
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
# Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.
# Ejemplo del resultado esperado:

lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

print(lista[0]) 
print(lista[1])
print(lista[2])
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
letra_verificada = {}
cantidad_letra = 5


'hola'
def verifivador_palabra(palabra_ingresada, palabra_secreta):
    for i in range(cantidad_letra):
        las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta[i]
        la_letra_existe_en_la_palabra = palabra_ingresada[i] in palabra_secreta

        if las_palabras_son_iguales:
            letra_verificada.append(f'[{palabra_ingresada[i]}]')
        elif la_letra_existe_en_la_palabra:
            letra_verificada.append(f'(, {palabra_ingresada[i]})')
        else:
            letra_verificada.append( palabra_ingresada[i])

verifivador_palabra('hola', 'calor')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 18
#      15         else:
#      16             letra_verificada.append( palabra_ingresada[i])
# ---> 18 verifivador_palabra('hola', 'calor')
#
# Cell In[3], line 16, in verifivador_palabra(palabra_ingresada, palabra_secreta)
#      14     letra_verificada.append(f'(, {palabra_ingresada[i]})')
#      15 else:
# ---> 16     letra_verificada.append( palabra_ingresada[i])
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
letras_verificadas = []
cantidad_letras = 5

def verificador_palabra(palabra_ingresada, palabra_secreta):
    for i in range(cantidad_letras):
        las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta[i] # True o False
        la_letra_existe_en_la_palabra = palabra_ingresada[i] in palabra_secreta 
        
        if las_palabras_son_iguales:
            letras_verificadas.append(f"[{palabra_ingresada[i]}]")
        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append(f"({palabra_ingresada[i]})")
        else:
            letras_verificadas.append(palabra_ingresada[i])
    
    return letras_verificadas

verificador_palabra('holas', 'calor')
